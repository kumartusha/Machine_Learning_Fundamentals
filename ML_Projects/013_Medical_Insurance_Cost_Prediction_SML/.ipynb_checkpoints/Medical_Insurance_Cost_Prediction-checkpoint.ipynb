# %% [markdown]
# # Medical Insurance Cost Prediction

# %%
# Import the Required Libraries for the Model or Project.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# ## Data Collection and Processing Step.

# %%
dataset = pd.read_csv("insurance.csv")
dataset
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# Check the number of rows and columns.
dataset.shape

# There are 1338 rows and the 7 columns.
# Out:
# (1338, 7)

# %%
#  Check the missing value.
dataset.isnull().sum()

#  It is very good to know that we dont have the missing dataset.
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Check the datatype of the features.
dataset.info()

# we have the features like the object int, and float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#  Check the statistics functions for the dataset.
dataset.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
dataset
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ## Data Analysis and Visualization Part

# %%
sns.set()
plt.figure(figsize=(7,7))
sns.distplot(dataset["age"], color="purple")
plt.title("Age Distribution")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2412\3048661523.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["age"], color="purple")

# %%
# Gender feature relationship Visualization.
plt.figure(figsize=(8,8))
sns.countplot(x = 'sex', data = dataset, palette="pastel")
plt.title("Sex Distribution")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2412\3114221584.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'sex', data = dataset, palette="pastel")

# %% [markdown]
# ## As we know about the BMI Range.
# ## Normal Range:- 18.5 to 24.9
# Below 18.5 -->  Underweight
# Above 24.9 -->  Overweight

# %%
# BMI Distribution.
plt.figure(figsize=(7,7))
sns.distplot(dataset["bmi"], color="purple")
plt.title("BMI Distribution")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2412\4277172159.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["bmi"], color="purple")

# %%
# children feature relationship Visualization.
plt.figure(figsize=(8,8))
sns.countplot(x = 'children', data = dataset, palette="pastel")
plt.title("Children Distribution")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2412\2032251509.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'children', data = dataset, palette="pastel")

# %%
# children feature relationship Visualization.
plt.figure(figsize=(8,8))
sns.countplot(x = 'smoker', data = dataset, palette="pastel")
plt.title("Smoker Distribution")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2412\4275812102.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'smoker', data = dataset, palette="pastel")

# %%
# children feature relationship Visualization.
plt.figure(figsize=(8,8))
sns.countplot(x = 'region', data = dataset, palette="pastel")
plt.title("Region Distribution")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2412\4002389586.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'region', data = dataset, palette="pastel")

# %%
# Charges Distribution.
plt.figure(figsize=(7,7))
sns.distplot(dataset["charges"], color="purple")
plt.title("Charge Distribution")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2412\4208182913.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["charges"], color="purple")

# %%
#  Check the distincts Value for the all features.

print(dataset["sex"].value_counts())
print(dataset["smoker"].value_counts())
print(dataset["region"].value_counts())
# Out:
# sex
# 1    676
# 0    662
# Name: count, dtype: int64
# smoker
# 0    1064
# 1     274
# Name: count, dtype: int64
# region
# 0    364
# 1    325
# 2    325
# 3    324
# Name: count, dtype: int64

# %% [markdown]
# ## Label Encoding into the dataset.

# %%
dataset = dataset.replace({"sex": {"male" : 1, "female": 0}, "smoker": {"yes" :1, "no" : 0}, "region": {"southeast": 0, "southwest": 1, "northwest" : 2, "northeast" : 3}})
# southeast --> 0
# southwest --> 1
# northwest --> 2
# northeast --> 3

# %% [markdown]
# dataset
#
# ## Split the dataset into the dependent and the independent variable.

# %%
x = dataset.drop("charges", axis=1)
y = dataset["charges"]

# %% [markdown]
# ## Training and testing Split.

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
print(x.shape, x_train.shape, x_test.shape)
print(x_train, x_test)
# Out:
# (1338, 6) (1070, 6) (268, 6)
#       age  sex     bmi  children  smoker  region
# 882    21    0  22.135         0       0       3
# 505    37    1  30.875         3       0       2
# 798    58    0  33.100         0       0       1
# 792    22    0  23.180         0       0       3
# 201    48    0  32.230         1       0       0
# ...   ...  ...     ...       ...     ...     ...
# 466    60    0  28.700         1       0       1
# 299    48    0  28.880         1       0       2
# 493    61    1  43.400         0       0       1
# 527    51    0  25.800         1       0       1
# 1192   58    0  32.395         1       0       3
#
# [1070 rows x 6 columns]       age  sex     bmi  children  smoker  region
# 17     23    1  23.845         0       0       3
# 1091   55    0  29.830         0       0       3
# 273    50    1  27.455         1       0       3
# 270    18    1  29.370         1       0       0
# 874    44    1  21.850         3       0       3
# ...

# %% [markdown]
# ## Linear Regression Model Implementation.

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#  Predicting the x_train Value.
training_data_predict = model.predict(x_train)

# %%
# R Squared Value  
error_rate = metrics.r2_score(training_data_predict , y_train)
print("R Squared Value.", error_rate * 100)
# Out:
# The Error Rate of the Model Perf. 66.98935862418944

# %%
# Visualize the Graph between the Actual and the predicted Value.
plt.figure(figsize=(7,7))
plt.scatter(y_train , training_data_predict)
plt.xlabel("Actual Data")
plt.ylabel("Prediction Data")
plt.title("Actual vs Predicted Value")
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted Value')

# %%
#  Predicting the x_test Value.
testing_data_predict = model.predict(x_test)

# %%
error_rate2 = metrics.r2_score(testing_data_predict , y_test)
print("The Error Rate of the Model Perf.", error_rate * 100)
# Out:
# The Error Rate of the Model Perf. 66.98935862418944

# %%
# Visualize the Graph between the Actual and the predicted Value.
plt.figure(figsize=(7,7))
plt.scatter(y_test , testing_data_predict)
plt.xlabel("Actual Data")
plt.ylabel("Prediction Data")
plt.title("Actual vs Predicted Value")
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted Value')

# %% [markdown]
# #  Build the Model Prediction System

# %%
#  Data for prediction on the new Data.
# southeast --> 0
# southwest --> 1
# northwest --> 2
# northeast --> 3
# new_data = (19,0,27.9,0,1,1)
new_data = (33,1,22.705,0,0,2)


#  we need to convert this input tuple or list into the numpy array.
new_numpy_array = np.asarray(new_data)

#  we also convert this data into the 2D datset as per the dependent Variable.
new_shaped_array = new_numpy_array.reshape(1,-1)

prediction = model.predict(new_shaped_array)
prediction
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3661.00197465])
