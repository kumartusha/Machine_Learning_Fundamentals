# %% [markdown]
# # Implementation of the matplotlibrary in the machine learning..

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# dataset = pd.DataFrame({'X': [90,34,76,56,86,97], 
#                         'Y': ["Part1", "Part2", "Part3", "Part4", "Part5", "Part6"]})
# dataset
x = [90,80,70,60,50, 40]
y = ["Part1", "Part2", "Part3", "Part4", "Part5", "Part6"]

x1 = [10,20,30,40,50,60]
y1 = ["Part7", "Part8", "Part9", "Part10", "Part11", "Part12"]

# %%
# plt.figure(figsize=(15,5))
# # Creating the chart for the particular dataframe..
# colors = ['red', 'blue', 'pink', 'yellow']
# plt.bar(x, y, color = colors, edgecolor = 'black')
# plt.xlabel("Marks of the Students")
# plt.ylabel("Categories of the Students")
# plt.title("Bar Graph for the Student Categories")
# plt.show()

# %%
plt.figure(figsize=(12,5))
plt.subplot(1, 2, 1)
plt.xlabel("Marks")
plt.ylabel("Category")
plt.plot(x,y)
plt.title("FIrst")

plt.subplot(1, 2, 2)
plt.xlabel("Marks")
plt.ylabel("Category")
plt.plot(x1,y1)
plt.title("Second")
# plt.legend()
# Out:
# Text(0.5, 1.0, 'Second')

# %%
plt.figure(figsize=(12,5))
plt.subplot(1, 2, 1)
plt.xlabel("Marks")
plt.ylabel("Category")
plt.bar(x,y)
plt.title("FIrst")

plt.subplot(1, 2, 2)
plt.xlabel("Marks")
plt.ylabel("Category")
plt.bar(x1,y1)
plt.title("Second")
# plt.legend()
# Out:
# Text(0.5, 1.0, 'Second')

# %%
dataset = pd.DataFrame({'Payment': [90,34,76,56,86,97], 
                        'Country': ["India", "USA", "Canada", "Demark", "USA", "UK"],
                        'PaymentMode': ["UPI", "Cash", "Credit", "Cash", "UPI", "Credit"]})
dgrouped = dataset.groupby(['PaymentMode', 'Country'])['Payment'].agg({'mean', 'sum'})
dgrouped
# Out:
#                      sum  mean
# PaymentMode Country
# Cash        Demark    56  56.0
#             USA       34  34.0
# Credit      Canada    76  76.0
#             UK        97  97.0
# UPI         India     90  90.0
#             USA       86  86.0

# %%
# x = ["Day1", "Day2", "Day3", "Day4", "Day5"]
# week1 = [98,67,87,56,87]
# week2 = [94,76,34,98,67]
#  Scatter Plot in the Matplotlib.
dataset = pd.read_excel(r"C:\Users\USER\OneDrive\Desktop\Github\Machine_Learning_Github\Machine_Learning_Fundamentals\01_Datasets\Placements.xlsx")
dataset

# plt.scatter(dataset['cgpa'], dataset['package'], marker ='*')
# # plt.plot(dataset['package'], dataset['cgpa'], marker ='o', color ='red')
# plt.title("Scatter Plot Graph")
# plt.xlabel("Package")
# plt.ylabel("cgpa")
# plt.legend(['Org'],)
# plt.show()
# plt.hist(dataset['cgpa'], bins=50)
# plt.show()
# plt.violinplot(dataset['cgpa'])
# plt.show()

plt.stem(dataset['cgpa'], markerfmt='d')
plt.show()

# %%
# dataset = pd.DataFrame({'Payment': [90,34,76,56,86,97], 
#                         'Country': ["India", "USA", "Canada", "Demark", "USA", "UK"],
#                         'PaymentMode': ["UPI", "Cash", "Credit", "Cash", "UPI", "Credit"]})
# # dataset
# ex = [0,0,0,0,0,0.1]
# plt.pie(dataset['Payment'],labels= dataset['Country'], center=(0,0), explode=ex)
# plt.legend(loc='lower left')
# plt.show()
# x = [90,34,76,56,86,97,34,76,56,86,97,34]
