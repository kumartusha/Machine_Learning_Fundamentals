# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# dataset = pd.read_excel(r"C:\Users\USER\OneDrive\Desktop\Github\Machine_Learning_Github\Machine_Learning_Fundamentals\010_Supervised_machine_learning\001_Regression_Analysis\multiple_regression_data.csv")
# dataset

dataset = pd.read_excel("multiple_linear_regression_dataset.xlsx")
dataset.shape
dataset
# Out:
#     age  experience  income
# 0    25           1   30450
# 1    30           3   35670
# 2    47           2   31580
# 3    32           5   40130
# 4    43          10   47830
# 5    51           7   41630
# 6    28           5   41340
# 7    33           4   37650
# 8    37           5   40250
# 9    39           8   45150
# 10   29           1   27840
# 11   47           9   46110
# 12   54           5   36720
# 13   51           4   34800
# 14   44          12   51300
# 15   41           6   38900
# 16   58          17   63600
# 17   23           1   30870
# 18   44           9   44190
# 19   37          10   48700

# %%
# dataset.isnull().sum()
# dataset.info()
# dataset.describe()

# %%
# sns.scatterplot(x = "Age", y = "Salary", data = dataset)
# sns.scatterplot(x = "Experience", y = "Salary", data = dataset)
# plt.show()

#  Pair plot in the SNS.
sns.pairplot(data = dataset)
plt.show()

# %%
sns.heatmap(data = dataset.corr(), annot=True)
plt.show()

# %%
#  Mandatory to convert into the 2D Array.
x = dataset.iloc[:, :-1]
y = dataset["income"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#  Algorithm for the Multiple Algorithm..
#  y = m1x1 + m2x2 + c
lr.score(x_test, y_test) * 100
# Out:
# 93.87098237077886

# %%
lr.coef_
# Out:
# array([-101.0592335 , 2154.80549277])

# %%
lr.intercept_
# Out:
# np.float64(31465.056418503933)

# %%
#  Y-Prediction..
# y_prd = 1676.38278101 * Age + (-136.234344) * experience + 
x.columns
# Out:
# Index(['age', 'experience'], dtype='object')

# %%
lr.predict(x_test)
# Out:
# array([31093.38107376, 31295.49954076, 40250.46080162, 34897.6958918 ])
