# %% [markdown]
# # Implementation of the Binary Logistic Regression ( Multiple Input and single Output)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\Github\Machine_Learning_Github\Machine_Learning_Fundamentals\010_Supervised_machine_learning\002_Classification_Learning\placement.csv")
dataset
# Out:
#     cgpa   iq  placement
# 0    6.8  123          1
# 1    5.9  106          0
# 2    5.3  121          0
# 3    7.4  132          1
# 4    5.8  142          0
# ..   ...  ...        ...
# 95   4.3  200          0
# 96   4.4   42          0
# 97   6.7  182          1
# 98   6.3  103          1
# 99   6.2  113          1
#
# [100 rows x 3 columns]

# %%
#  Prediction of the placement based on the CGPA and the IQ level.

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(x = "cgpa", y = "iq", data = dataset, hue = "placement")
# plt.legend(loc = 1)
plt.show()

# %%
x = dataset.iloc[:,: -1]
y = dataset["placement"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test, y_test) * 100
# Out:
# 85.0

# %%
lr.predict([[5.9, 106]])
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
lr.coef_
# Out:
# array([[3.08692655, 0.00887102]])

# %%
lr.intercept_
# Out:
# array([-19.61194721])

# %%
# How to build the decision boundary..
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(),clf = lr)
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# <Axes: >
