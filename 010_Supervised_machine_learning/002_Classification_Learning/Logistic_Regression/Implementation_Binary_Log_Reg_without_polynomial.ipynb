# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\Github\Machine_Learning_Github\Machine_Learning_Fundamentals\010_Supervised_machine_learning\002_Classification_Learning\polynomial_logistic_regression.csv")
dataset.head(3)
# Out:
#    Feature_1  Feature_2  Target
# 0       3.75      11.01       0
# 1       9.51       4.54       0
# 2       7.32      19.23       1

# %%
sns.scatterplot(x = "Feature_1", y = "Feature_2", data = dataset, hue = "Target")
plt.show()

# %%
x = dataset.iloc[ :, : -1]
y = dataset["Target"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test, y_test) * 100
# Out:
# 100.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf = lr)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Implementation using the polynomial feature
